# %% [markdown]
# https://seaborn.pydata.org/

# %% [markdown]
# ![seaborn.PNG](data:image/png;base64,...)

# %% [markdown]
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
#
#
# https://seaborn.pydata.org/tutorial/function_overview.html

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# https://github.com/allisonhorst/palmerpenguins

# %%
df = sns.load_dataset('iris')
penguins = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# #matplotlib vs seaborn

# %%
import matplotlib.pyplot as plt

# %%
rng = np.random.RandomState(0)
x = np.linespace(0,10,500)
y = np.cumsum()

# %%
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2)

# %%
df=pd.DataFrame(y,columns=['A','B','C','D','E','F'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3458/2416384121.py in <module>
# ----> 1 df=pd.DataFrame(y,columns=['A','B','C','D','E','F'])
#
# NameError: name 'y' is not defined

# %%
sns.lineplot(data=df,x='x',y='A')
sns.lineplot(data=df,x='x',y='B')
sns.lineplot(data=df,x='x',y='C')
sns.lineplot(data=df,x='x',y='D')
sns.lineplot(data=df,x='x',y='E')
sns.lineplot(data=df,x='x',y='F')
plt.legend('ABCDEF',ncol=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3458/2226242096.py in <module>
# ----> 1 sns.lineplot(data=df,x='x',y='A')
#       2 sns.lineplot(data=df,x='x',y='B')
#       3 sns.lineplot(data=df,x='x',y='C')
#       4 sns.lineplot(data=df,x='x',y='D')
#       5 sns.lineplot(data=df,x='x',y='E')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
# ...

# %%
sns.lineplot(data=df.set_index('x'))#ver la diferencia quitando el .set_index('x')

# %% [markdown]
# ### Scatter plots

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width')

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width',style='species',hue='species')#style separa por species y hue me pone colores

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width',size='petal_width')

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width',size='petal_width',hue='species')

# %%
sns.relplot(data=df,x='petal_length',y='petal_width',size='petal_width',hue='species')

# %% [markdown]
# # Joint

# %%
sns.jointplot(data=df,x='petal_length',y='petal_width')

# %%
sns.jointplot?

# %% [markdown]
# # Joint Grid

# %%
joint_func=sns.JointGrid(data=df,x='petal_length',y='petal_width')
joint_func.plot(sns.scatterplot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3458/3766102288.py in <module>
#       1 joint_func=sns.JointGrid(data=df,x='petal_length',y='petal_width')
# ----> 2 joint_func.plot(sns.scatterplot)
#
# TypeError: plot() missing 1 required positional argument: 'marginal_func'

# %% [markdown]
# # Histogram

# %%
xs=np.random.normal(size=1000)
ax=sns.displot(xs)

# %% [markdown]
# By default, displot()/histplot() choose a default bin size based on the variance of the data and the number of observations.
#
# But you should not be over-reliant on such automatic approaches, because they depend on particular assumptions about the structure of your data. It is always advisable to check that your impressions of the distribution are consistent across different bin sizes

# %%
xs=np.random.exponential(size=1000)
ax=sns.displot(xs)

# %%
ax=sns.displot(xs,bins=5)

# %%
ax=sns.histplot(xs)

# %% [markdown]
# stat{“count”, “frequency”, “density”, “probability”}
# Aggregate statistic to compute in each bin.
#
# **count** shows the number of observations
#
# **frequency** shows the number of observations divided by the bin width
#
# **density** normalizes counts so that the area of the histogram is 1
#
# probability normalizes counts so that the sum of the bar heights is 1

# %%
ax=sns.histplot(xs,bins=5,stat='density',label='cosas')
ax.legend()

# %%
ax=sns.histplot(xs,bins=5,stat='probability',label='cosas')
ax.legend()

# %%
ax=sns.histplot(xs,bins=50,kde='True',stat='probability',label='cosas')
ax.legend()

# %% [markdown]
# # Pairwise relationships

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='species')

# %%
sns.pairplot(df[['sepal',diag_kind='kde',hue='species')

# %% [markdown]
# ### Linear relationships

# %%
sns.lmplot(data=df,x='petal_length',y='petal_width',hue='species')#podemos pintar directamente la regresion lineal

# %% [markdown]
# # Categorical Data
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# #### swarm and strip plot

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(data=penguins,x='species',y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=penguins,x='species',y='body_mass_g',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=df,x='species',y='petal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.boxplot(data=df,x='species',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.displot(data=penguins,x='species',y='body_mass_g',col='species',bins=50)

# %%
sns.violinplot(data=penguins,x='species',y='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.stripplot(data=penguins,x='bill_length_mm',y='species',hue='sex')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %%
sns.swarmplot(data=penguins,x='bill_length_mm',y='species',hue='sex')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %% [markdown]
# ### Ejercicio
#
# ![violinplot.PNG](data:image/png;base64,...)

# %% [markdown]
# Order by decreasing median

# %%
fig,ax=plt.subplots(figsize=(10,8))
sns.set(style="darkgrid")
sns.violinplot(data=df,x='species',y='sepal_length',order=['virginica','versicolor','setosa'],palette=[sns.color_palette('deep')[i] for i in [0,2,3]],ax=ax)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot?

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=penguins,x='species',y='bill_length_mm',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.countplot(data=penguins,x='species',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # Point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(data=penguins,x='species',y='bill_length_mm',hue='sex',ci='sd')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.pointplot(data=penguins,x='species',y='bill_length_mm',hue='sex',ci='sd',estimator=np.min)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,cmap='bwr')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True,cmap='mako')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cluster map
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %% [markdown]
# # PANDAS
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# #### Parallel coordinates plot
# Parallel plot or Parallel Coordinates Plots allow to compare the feature of several individual observations on a set of numerical variables

# %%
from pandas.plotting import parallel_coordinates

# %% [markdown]
# #### autocorrelation plots
#
# Autocorrelation plots are often used for checking randomness in time series. This is done by computing autocorrelations for data values at varying time lags. If time series is random, such autocorrelations should be near zero for any and all time-lag separations. If time series is non-random then one or more of the autocorrelations will be significantly non-zero. The horizontal lines displayed in the plot correspond to 95% and 99% confidence bands.

# %%
from pandas.plotting import autocorrelation_plot
