# %% [markdown]
# https://seaborn.pydata.org/

# %% [markdown]
# ![seaborn.PNG](data:image/png;base64,...)

# %% [markdown]
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
#
#
# https://seaborn.pydata.org/tutorial/function_overview.html

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#
# https://github.com/allisonhorst/palmerpenguins

# %%
df=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # matplotlib vs seaborn

# %%
import matplotlib.pyplot as plt

# %%
rng=np.random.RandomState(0)
x=np.linspace(0,10,500)
y=np.cumsum(rng.randn(500,6),0)

# %%
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2)

# %%
df=pd.DataFrame(y,columns=['A','B','C','D','E','F'])
df['x']=x

# %%
df.head()
# Out:
#           A         B         C         D         E         F        x
# 0  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  0.00000
# 1  2.714141  0.248800  0.875519  2.651492  2.011602  0.476996  0.02004
# 2  3.475178  0.370475  1.319382  2.985166  3.505681  0.271837  0.04008
# 3  3.788246 -0.483621 -1.233607  3.638785  4.370117 -0.470328  0.06012
# 4  6.058001 -1.937986 -1.187849  3.451601  5.902896  0.999031  0.08016

# %%
sns.lineplot(data=df,x='x',y='A')
sns.lineplot(data=df,x='x',y='B')
sns.lineplot(data=df,x='x',y='C')
sns.lineplot(data=df,x='x',y='D')
sns.lineplot(data=df,x='x',y='E')
sns.lineplot(data=df,x='x',y='F')
plt.legend('ABCDEF',ncol=2)

# %%
sns.lineplot(data=df.set_index('x'))
# Out:
# <AxesSubplot:xlabel='x'>

# %% [markdown]
# ### Scatter plots

# %%
df=sns.load_dataset('iris')

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width' )

# %%
sns.relplot(data=df,x='sepal_length',
            y='sepal_width',
            style='species')

# %%
sns.relplot(data=df,x='sepal_length',y='sepal_width',
            style='species',
            hue='species')

# %%
sns.relplot(data=df,x='sepal_length',
            y='sepal_width',
            size='petal_width',
           hue='species')

# %%
sns.relplot(data=df,x='petal_length',
            y='petal_width',
            #size='petal_width',
           hue='species')

# %% [markdown]
# # Joint

# %%
sns.jointplot(data=df,x='sepal_length',y='sepal_width')

# %%
sns.JointGrid?

# %% [markdown]
# # Joint Grid

# %%
joint_func=sns.JointGrid(data=df,x='sepal_length',y='sepal_width')
joint_func.plot(sns.scatterplot,sns.histplot)

# %% [markdown]
# # Histogram

# %%
xs=np.random.normal(size=1000)
ax=sns.displot(xs)

# %% [markdown]
# By default, displot()/histplot() choose a default bin size based on the variance of the data and the number of observations.
#
# But you should not be over-reliant on such automatic approaches, because they depend on particular assumptions about the structure of your data. It is always advisable to check that your impressions of the distribution are consistent across different bin sizes

# %%
xs=np.random.exponential(size=1000)
ax=sns.histplot(xs)

# %%
ax=sns.histplot(xs,bins=5)

# %% [markdown]
# stat{“count”, “frequency”, “density”, “probability”}
# Aggregate statistic to compute in each bin.
#
# **count** shows the number of observations
#
# **frequency** shows the number of observations divided by the bin width
#
# **density** normalizes counts so that the area of the histogram is 1
#
# probability normalizes counts so that the sum of the bar heights is 1

# %%
sns.histplot?

# %%
ax=sns.histplot(xs,
                bins=20,
                kde='True',
                stat='density',
                label='cosas')
ax.legend()

# %%
sns.displot(data=df,
            x='petal_width',
            hue='species',
            legend=True);

# %%
sns.displot(data=df,
            x='petal_width',
            hue='species',
            legend=True,
            multiple='dodge');

# %%
sns.displot(data=df,
            x='petal_width',
            hue='species',
            legend=True,
            kind='kde',
            fill=True);

# %%
sns.displot(data=df,
            x='petal_width',
            col='species');

# %% [markdown]
# # Pairwise relationships

# %%
sns.pairplot(df,hue='species')

# %%
sns.pairplot(df[['sepal_length','sepal_width','species']],
             diag_kind='kde',
             hue='species')

# %% [markdown]
# ### Linear relationships

# %%
sns.lmplot(data=df,
           x='petal_length',
           y='petal_width',
           hue='species')

# %% [markdown]
# # Categorical Data
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# # Boxplot
# ![image.png](data:image/png;base64,...)

# %%
penguins=sns.load_dataset('penguins')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.boxplot(data=penguins,
            x='species',
            y='body_mass_g',
           hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [raw]
# sns.boxplot(data=df,
#             x='species',
#             y='petal_width')

# %%
sns.displot(data=penguins,
            x='body_mass_g',
            col='species',
            hue='sex',
            bins=50)

# %%
sns.boxenplot?

# %%
sns.boxenplot(data=penguins,x='species',y='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.violinplot(data=penguins,
               x='species',
               y='bill_length_mm')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.violinplot?

# %% [markdown]
# #### swarm and strip plot

# %%
sns.boxplot(data=penguins,
            x='species',
            y='body_mass_g',
            hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=penguins,
              x='bill_length_mm',
              y='species',
              hue='sex')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %%
sns.swarmplot(data=penguins,
              x='bill_length_mm',
              y='species',
              hue='sex')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='species'>

# %% [markdown]
# ### Ejercicio
#
# ![violinplot.PNG](data:image/png;base64,...)

# %% [markdown]
# Order by decreasing median

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.set_theme(style='darkgrid')

# %%
np.array(sns.color_palette('deep'))
# Out:
# array([[0.29803922, 0.44705882, 0.69019608],
#        [0.86666667, 0.51764706, 0.32156863],
#        [0.33333333, 0.65882353, 0.40784314],
#        [0.76862745, 0.30588235, 0.32156863],
#        [0.50588235, 0.44705882, 0.70196078],
#        [0.57647059, 0.47058824, 0.37647059],
#        [0.85490196, 0.54509804, 0.76470588],
#        [0.54901961, 0.54901961, 0.54901961],
#        [0.8       , 0.7254902 , 0.45490196],
#        [0.39215686, 0.70980392, 0.80392157]])

# %%
palette=np.array([sns.color_palette('deep')[0],
                  sns.color_palette('deep')[2],
                  sns.color_palette('deep')[3]])
palette
# Out:
# array([[0.29803922, 0.44705882, 0.69019608],
#        [0.33333333, 0.65882353, 0.40784314],
#        [0.76862745, 0.30588235, 0.32156863]])

# %%
my_order=iris.groupby(by=['species'])['sepal_length'].median()
my_order=my_order.iloc[::-1].index

# %%
fig,ax=plt.subplots(figsize=(10,8))
sns.violinplot(data=iris,
               x='species',
               y='sepal_length',
               order=my_order,
               palette=[sns.color_palette('deep')[i] for i in [0,2,3]],
               ax=ax);
#ax.grid(True)
#ax.set_title('violin plot prueba')

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=penguins,
            x='species',
            y='bill_length_mm',
            hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.countplot(data=penguins,
              x='species',
              hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
# ?sns.countplot

# %% [markdown]
# # Point plot
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.pointplot(data=penguins,
              x='species',
              y='bill_length_mm',
              estimator=np.mean,
              hue='sex',
              ax=ax,
              ci='sd');

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.pointplot(data=iris,
              x='species',
              y='petal_width',
              estimator=np.mean,
              #hue='gender',
              ax=ax,
              ci='sd');

# %%
sns.pointplot?

# %%
sns.pointplot(data=penguins,
              x='species',
              y='bill_length_mm',
              hue='sex',
              ci='sd',
              estimator=np.min)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# ### Heatmap

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
mean_flipper=penguins.groupby(['species','island'])['flipper_length_mm'].mean()
mean_flipper
# Out:
# species    island
# Adelie     Biscoe       188.795455
#            Dream        189.732143
#            Torgersen    191.196078
# Chinstrap  Dream        195.823529
# Gentoo     Biscoe       217.186992
# Name: flipper_length_mm, dtype: float64

# %%
mean_flipper.unstack()
# Out:
# island         Biscoe       Dream   Torgersen
# species
# Adelie     188.795455  189.732143  191.196078
# Chinstrap         NaN  195.823529         NaN
# Gentoo     217.186992         NaN         NaN

# %%
sns.heatmap(mean_flipper.unstack())
# Out:
# <AxesSubplot:xlabel='island', ylabel='species'>

# %%
sns.heatmap(iris.corr(),
            annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(),annot=True,cmap='bwr')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(),annot=True,cmap='mako')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cluster map
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_sin_species=iris.drop('species',axis=1)

# %%
sns.clustermap(iris_sin_species,cmap='mako')

# %% [markdown]
# # PANDAS
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig,ax=plt.subplots(figsize=(10,8))

iris.plot(x='petal_length',y='sepal_length',ax=ax)
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
fig,ax=plt.subplots(figsize=(10,8))

iris.plot(x='petal_length',y='sepal_length',ax=ax,linestyle='',marker='.')
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %% [markdown]
# #### Parallel coordinates plot
# Parallel plot or Parallel Coordinates Plots allow to compare the feature of several individual observations on a set of numerical variables

# %%
from pandas.plotting import parallel_coordinates

# %%
fig,ax=plt.subplots(figsize=(12,8))

parallel_coordinates(frame=iris,class_column='species',ax=ax,colormap=plt.get_cmap('viridis'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### autocorrelation plots
#
# Autocorrelation plots are often used for checking randomness in time series. This is done by computing autocorrelations for data values at varying time lags. If time series is random, such autocorrelations should be near zero for any and all time-lag separations. If time series is non-random then one or more of the autocorrelations will be significantly non-zero. The horizontal lines displayed in the plot correspond to 95% and 99% confidence bands.

# %%
from pandas.plotting import autocorrelation_plot
